# %%
#先导包
import numpy as np
from scipy.linalg import svd
from PIL import Image
import matplotlib.pyplot as plt

# %%
#加载图片
image = Image.open('songhao.jpg') 
image=image.convert('L')#image.convert('L')  转成灰度图
A = np.array(image)
# 显示原图像
plt.imshow(A, cmap=plt.cm.gray, interpolation='nearest')
plt.show()

# %%
# 取前k个特征，对图像进行还原
def get_image_feature(s, k):
    # 对于S，只保留前K个特征值
    s_temp = np.zeros(s.shape[0])
    s_temp[0:k] = s[0:k]
    s = s_temp * np.identity(s.shape[0])
    # 用新的s_temp，以及p,q重构A
    temp = np.dot(p,s)
    temp = np.dot(temp,q)
    plt.imshow(temp, cmap=plt.cm.gray, interpolation='nearest')
    plt.show()
    print(A-temp)

# %%
A.shape
# Out:
# (1080, 1920)

# %%
p,s,q = svd(A, full_matrices=False)
get_image_feature(s, 5)
# Out:
# [[ 36.54862901  36.21321717  35.44014482 ...  48.1577211   48.04318813
#    47.39258356]
#  [ 36.4394918   36.10490685  35.33241701 ...  48.59993025  48.49071245
#    47.83277298]
#  [ 37.38535214  37.05108096  36.27853223 ...  49.06127361  48.95087061
#    48.29082442]
#  ...
#  [ -7.27823295  -8.19058796  -9.90687196 ...  13.66043767  12.97455529
#    12.18291809]
#  [ -7.72320172  -8.6378457  -10.35701553 ...  13.38071629  12.70465668
#    11.92475382]
#  [ -8.2804568   -9.19696912 -10.91876426 ...  13.52223467  12.86227392
#    12.09080649]]

# %%
get_image_feature(s, 50)
# Out:
# [[  6.16120161   5.65658421   5.30995478 ... -12.12969023 -15.05757549
#   -16.3585329 ]
#  [  4.47510286   3.90385359   3.46841491 ...  -9.8163916  -12.6626932
#   -13.91487211]
#  [  4.04879258   3.46400827   3.00937599 ...  -7.942058   -10.6270355
#   -11.98308526]
#  ...
#  [ -6.57836542  -7.52349468  -9.65937544 ...  -1.96798028  -2.78425285
#    -1.77962413]
#  [ -7.27807767  -8.24380584 -10.35908514 ...  -2.28306748  -2.91901033
#    -1.73226651]
#  [ -7.63756269  -8.54457863 -10.51806512 ...  -2.00595188  -2.26384138
#    -0.78723465]]

# %%
get_image_feature(s, 500)
# Out:
# [[ 0.1834103   0.02490207 -0.05301292 ...  1.51905393  0.15095825
#   -2.06158328]
#  [ 0.51298159  0.13171357 -0.08210953 ...  1.09114606  1.98511026
#    2.05372368]
#  [-0.60822184 -0.48246363 -0.28076815 ... -0.43251541 -0.09645248
#    0.78786204]
#  ...
#  [ 0.32648354  0.4353288   0.3604585  ... -0.53310489  0.09678338
#    1.57061554]
#  [ 0.08425995  0.02801471  0.01784979 ... -0.46437322 -0.37025745
#   -0.24679271]
#  [-1.01634114 -0.87287181 -0.45046038 ...  0.2604104  -0.56692775
#   -2.11475934]]
