# %%
import pandas as pd
dataset=pd.read_csv('pollution.csv',index_col=0)#index_col=0,用第一列的数据做索引
dataset#书签 看到老师的教程2:15:52了
# Out:
#                      pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# date
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79     0     0
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68     0     0
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57     0     0
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36     1     0
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25     2     0
# ...                        ...  ...   ...     ...     ...      ...   ...   ...
# 2014-12-31 19:00:00        8.0  -23  -2.0  1034.0      NW   231.97     0     0
# 2014-12-31 20:00:00       10.0  -22  -3.0  1034.0      NW   237.78     0     0
# 2014-12-31 21:00:00       10.0  -22  -3.0  1034.0      NW   242.70     0     0
# 2014-12-31 22:00:00        8.0  -22  -4.0  1034.0      NW   246.72     0     0
# 2014-12-31 23:00:00       12.0  -21  -3.0  1034.0      NW   249.85     0     0
#
# [43800 rows x 8 columns]

# %%
values=dataset.values
values
# Out:
# array([[129.0, -16, -4.0, ..., 1.79, 0, 0],
#        [148.0, -15, -4.0, ..., 2.68, 0, 0],
#        [159.0, -11, -5.0, ..., 3.57, 0, 0],
#        ...,
#        [10.0, -22, -3.0, ..., 242.7, 0, 0],
#        [8.0, -22, -4.0, ..., 246.72, 0, 0],
#        [12.0, -21, -3.0, ..., 249.85, 0, 0]], dtype=object)

# %%
import matplotlib.pyplot as plt
#一共有8个特征
# groups=[0,1,2,3,4,5,6,7]
i=1
for group in range(8):
    plt.subplot(8,1,i)#8行一列第i行
    plt.plot(values[:,group])
    plt.title(dataset.columns[group])
    i=i+1
plt.show()

# %%
dataset['wnd_dir'].value_counts()
# Out:
# SE    15290
# NW    14130
# cv     9384
# NE     4996
# Name: wnd_dir, dtype: int64

# %%
#将分类特征wnd_dir进行标签编码
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
values[:,4]=encoder.fit_transform(values[:,4])
#设置数据类型为float32
values=values.astype('float32')
values
# Out:
# array([[129.  , -16.  ,  -4.  , ...,   1.79,   0.  ,   0.  ],
#        [148.  , -15.  ,  -4.  , ...,   2.68,   0.  ,   0.  ],
#        [159.  , -11.  ,  -5.  , ...,   3.57,   0.  ,   0.  ],
#        ...,
#        [ 10.  , -22.  ,  -3.  , ..., 242.7 ,   0.  ,   0.  ],
#        [  8.  , -22.  ,  -4.  , ..., 246.72,   0.  ,   0.  ],
#        [ 12.  , -21.  ,  -3.  , ..., 249.85,   0.  ,   0.  ]],
#       dtype=float32)

# %%
values[:,4]
# Out:
# array([2., 2., 2., ..., 1., 1., 1.], dtype=float32)

# %%
#数据规范化一下
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaled=scaler.fit_transform(values)
scaled.shape
# Out:
# (43800, 8)

# %%
# 将时间序列数据转换为适用于监督学习的数据
"""
data:观察序列
n_in:观察数据input(x)的步长值,范围[1,len(data)],默认为1
n_out:output(y)的步长,默认为1 
dropnan:是否删除nan行
返回值：适用于监督学习的DataFrame
"""
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df =pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]
    # 预测序列 (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # 去掉NaN行
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# 将时间序列数据转换为适合监督学习的数据
reframed = series_to_supervised(scaled, 1, 1)
reframed.to_csv('reframed-1.csv')
reframed
# Out:
#        var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1       0.129779   0.352941   0.245902   0.527273   0.666667   0.002290
# 2       0.148893   0.367647   0.245902   0.527273   0.666667   0.003811
# 3       0.159960   0.426471   0.229508   0.545454   0.666667   0.005332
# 4       0.182093   0.485294   0.229508   0.563637   0.666667   0.008391
# 5       0.138833   0.485294   0.229508   0.563637   0.666667   0.009912
# ...          ...        ...        ...        ...        ...        ...
# 43795   0.010060   0.264706   0.278689   0.763638   0.333333   0.385730
# 43796   0.008048   0.250000   0.278689   0.781818   0.333333   0.395659
# 43797   0.010060   0.264706   0.262295   0.781818   0.333333   0.405588
# 43798   0.010060   0.264706   0.262295   0.781818   0.333333   0.413996
# 43799   0.008048   0.264706   0.245902   0.781818   0.333333   0.420866
#
#        var7(t-1)  var8(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)  \
# 1       0.000000        0.0  0.148893  0.367647  0.245902  0.527273  0.666667
# 2       0.000000        0.0  0.159960  0.426471  0.229508  0.545454  0.666667
# 3       0.000000        0.0  0.182093  0.485294  0.229508  0.563637  0.666667
# 4       0.037037        0.0  0.138833  0.485294  0.229508  0.563637  0.666667
# 5       0.074074        0.0  0.109658  0.485294  0.213115  0.563637  0.666667
# ...          ...        ...       ...       ...       ...       ...       ...
# 43795   0.000000        0.0  0.008048  0.250000  0.278689  0.781818  0.333333
# 43796   0.000000        0.0  0.010060  0.264706  0.262295  0.781818  0.333333
# 43797   0.000000        0.0  0.010060  0.264706  0.262295  0.781818  0.333333
# 43798   0.000000        0.0  0.008048  0.264706  0.245902  0.781818  0.333333
# 43799   0.000000        0.0  0.012072  0.279412  0.262295  0.781818  0.333333
#
#         var6(t)   var7(t)  var8(t)
# 1      0.003811  0.000000      0.0
# 2      0.005332  0.000000      0.0
# 3      0.008391  0.037037      0.0
# 4      0.009912  0.074074      0.0
# 5      0.011433  0.111111      0.0
# ...         ...       ...      ...
# 43795  0.395659  0.000000      0.0
# 43796  0.405588  0.000000      0.0
# 43797  0.413996  0.000000      0.0
# 43798  0.420866  0.000000      0.0
# 43799  0.426216  0.000000      0.0
#
# [43799 rows x 16 columns]

# %%
#去掉不需要预测的列，即var2(t) var3(t) var4(t) var5(t) var6(t) var7(t)  var8(t)
reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
reframed.to_csv('reframed-2.csv')
reframed
# Out:
#        var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1       0.129779   0.352941   0.245902   0.527273   0.666667   0.002290
# 2       0.148893   0.367647   0.245902   0.527273   0.666667   0.003811
# 3       0.159960   0.426471   0.229508   0.545454   0.666667   0.005332
# 4       0.182093   0.485294   0.229508   0.563637   0.666667   0.008391
# 5       0.138833   0.485294   0.229508   0.563637   0.666667   0.009912
# ...          ...        ...        ...        ...        ...        ...
# 43795   0.010060   0.264706   0.278689   0.763638   0.333333   0.385730
# 43796   0.008048   0.250000   0.278689   0.781818   0.333333   0.395659
# 43797   0.010060   0.264706   0.262295   0.781818   0.333333   0.405588
# 43798   0.010060   0.264706   0.262295   0.781818   0.333333   0.413996
# 43799   0.008048   0.264706   0.245902   0.781818   0.333333   0.420866
#
#        var7(t-1)  var8(t-1)   var1(t)
# 1       0.000000        0.0  0.148893
# 2       0.000000        0.0  0.159960
# 3       0.000000        0.0  0.182093
# 4       0.037037        0.0  0.138833
# 5       0.074074        0.0  0.109658
# ...          ...        ...       ...
# 43795   0.000000        0.0  0.008048
# 43796   0.000000        0.0  0.010060
# 43797   0.000000        0.0  0.010060
# 43798   0.000000        0.0  0.008048
# 43799   0.000000        0.0  0.012072
#
# [43799 rows x 9 columns]

# %%
#数据集切分 80%作为训练集 20%作为测试集
values=reframed.values
n_train_hours=int(len(values)*0.8)
train=values[:n_train_hours,:]
test=values[n_train_hours:,:]
train_X,train_y=train[:,:-1],train[:,-1]
test_X,test_y=test[:,:-1],test[:,-1]
train_X.shape
# Out:
# (35039, 8)

# %%
train_y.shape
# Out:
# (35039,)

# %%
#转换为3D格式[样本数，时间步，特征数]
train_X=train_X.reshape((train_X.shape[0],1,train_X.shape[1]))
test_X=test_X.reshape((test_X.shape[0],1,test_X.shape[1]))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM

#设置网络模型 
model=Sequential()
model.add(LSTM(50,input_shape=(train_X.shape[1],train_X.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')
#模型训练
result=model.fit(train_X,train_y,epochs=10,batch_size=64,validation_data=(test_X,test_y),verbose=2,shuffle=False)
# Out:
# Epoch 1/10
# 548/548 - 12s - loss: 0.0035 - val_loss: 0.0103
# Epoch 2/10
# 548/548 - 9s - loss: 9.9273e-04 - val_loss: 0.0040
# Epoch 3/10
# 548/548 - 10s - loss: 8.2870e-04 - val_loss: 0.0022
# Epoch 4/10
# 548/548 - 10s - loss: 8.0271e-04 - val_loss: 0.0017
# Epoch 5/10
# 548/548 - 10s - loss: 7.9904e-04 - val_loss: 0.0015
# Epoch 6/10
# 548/548 - 11s - loss: 7.9837e-04 - val_loss: 0.0013
# Epoch 7/10
# 548/548 - 9s - loss: 7.9858e-04 - val_loss: 0.0012
# Epoch 8/10
# 548/548 - 11s - loss: 7.9906e-04 - val_loss: 0.0011
# Epoch 9/10
# 548/548 - 11s - loss: 7.9917e-04 - val_loss: 0.0011
# Epoch 10/10
# 548/548 - 11s - loss: 7.9890e-04 - val_loss: 0.0011

# %%
#模型预测
train_predict=model.predict(train_X)
test_predict=model.predict(test_X)
test_predict
# Out:
# array([[0.02891832],
#        [0.02976774],
#        [0.05492158],
#        ...,
#        [0.01492503],
#        [0.01489234],
#        [0.01323047]], dtype=float32)

# %%
line1=result.history['loss']
line2=result.history['val_loss']
plt.plot(line1,label='train',c='g')
plt.plot(line2,label='test',c='r')
plt.legend(loc='best')
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 50)                11800
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 11,851
# Trainable params: 11,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
#呈现原始诗句，训练结果，预测结果
def plot_img(source_data_set,train_predict,test_predict):
    #原始的数据（蓝色）
    plt.plot(source_data_set[:,-1],label='real',c='b')
    #原始的数据（绿色）
    plt.plot([x for x in train_predict],label='train_predict',c='g') 
    #预测结果（红色）
    temp=[None for _ in train_predict]+[x for x in test_predict]
    temp=[[x] for x in temp]
    plt.plot(temp,label='test_predict',c='r') 
    plt.legend(loc='best')
    plt.show()
#绘制预测结果与实际结果的对比    
plot_img(values,train_predict,test_predict)

# %%
[None for _ in train_predict]+[x for x in test_predict]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]
